# %% [markdown]
# # Rescaling Atomic units
#
# ### Notation:
# one can say m=5kg than {m} = 5 and [m] = kg in other words { } means value and [ ] unit.
#
# HAU = Hartree Atomic Units
#
# RAU = Rescaled Atomic Units
#
# ### Atomic base units:
# - action: $\hbar = 1.054571817 \times 10−34 Js$
#
# \begin{align*}
# \{\hbar\}_{SI} &= 1.054571817 \times 10^{-34}; \quad [\hbar]_{SI} = Js \\
# \{\hbar\}_{HAU} &= 1; \quad [\hbar]_{HAU} = 1.054571817 \times 10^{-34} Js\\
# \{\hbar\}_{RAU} &= X_h; \quad [\hbar]_{RAU} = \underbrace{\frac{1}{X_h}}_{r_h} 1.054571817 \times 10^{-34} Js
# \end{align*}
#
# - elementary charge: $e_0 = 1.602176634 \times 10^{−19} C$
#
# \begin{align*}
# \{e_0\}_{SI} &= 1.602176634 \times 10^{-19}; \quad [e_0]_{SI} = C \\
# \{e_0\}_{HAU} &= 1; \quad [e_0]_{HAU} = 1.602176634 \times 10^{-19} C\\
# \{e_0\}_{RAU} &= X_e; \quad [e_0]_{RAU} = \underbrace{\frac{1}{X_e}}_{r_e} 1.602176634 \times 10^{-19} C
# \end{align*}
#
# - electron rest mass: $m_e = 9.1093837139(28) \times 10^{−31} kg$
#
# \begin{align*}
# \{m_e\}_{SI} &= 9.1093837139 \times 10^{-31}; \quad [m_e]_{SI} = kg \\
# \{m_e\}_{HAU} &= 1; \quad [m_e]_{HAU} = 9.1093837139 \times 10^{-31} kg\\
# \{m_e\}_{RAU} &= X_m; \quad [m_e]_{RAU} = \underbrace{\frac{1}{X_m}}_{r_m} 9.1093837139 \times 10^{-31} kg
# \end{align*}
#
# - permittivity: $\kappa_0 = 4 \pi \epsilon_0 = 1.11265005620 \times 10^{−10} F/m$
#
# \begin{align*}
# \{\kappa_0\}_{SI} &= 1.11265005620 \times 10^{-10}; \quad [\kappa_0]_{SI} = F/m \\
# \{\kappa_0\}_{HAU} &= 1; \quad [\kappa_0]_{HAU} = 1.11265005620 \times 10^{-10} F/m\\
# \{\kappa_0\}_{RAU} &= X_k; \quad [\kappa_0]_{RAU} = \underbrace{\frac{1}{X_k}}_{r_k} 1.11265005620 \times 10^{-10} F/m
# \end{align*}
#
# ### Derived units
#
# - length:
#   Bohr radius
#   \begin{align*} ⁠
#   a_{0} = \frac{\kappa_0 \hbar ^{2}}{m_{e}e_0^{2}} &= \frac{\{\kappa_0\}_{SI} [\kappa_0]_{SI} \, (\{\hbar\}_{SI} [\hbar]_{SI})^2 }{ \{m_e\}_{SI} [m_e]_{SI} \, (\{e_0\}_{SI} [e_0]_{SI})^{2}}\\
#   &= \frac{\{\kappa_0\}_{SI} \, \{\hbar\}_{SI}^2 }{ \{m_e\}_{SI} \, \{e_0\}_{SI}^{2}} \, \frac{ [\kappa_0]_{SI} \, [\hbar]_{SI}^2 }{ [m_e]_{SI} \, [e_0]_{SI}^{2}}\\
#   &= \frac{1.11265005620 \times 10−10 \cdot (1.054571817 \times 10−34)^2 }{ 9.1093837139 \times 10−31 \cdot (1.602176634 \times 10−19)^{2}} \, \frac{ F/m \, (Js)^2 }{ kg \, C^2}\\
#   &= 5.2917720989499097 \times 10^{-11} m\\
#   &\Rightarrow \{ a_{0} \}_{SI}=5.2917720989499097 \times 10^{-11}; \qquad  [a_{0}]_{SI}=m\\
#   \end{align*}
#
#   \begin{align*}
#   a_{0} &= \frac{\{\kappa_0\}_{HAU} \, \{\hbar\}_{HAU}^2 }{ \{m_e\}_{HAU} \, \{e_0\}_{HAU}^{2}} \, \frac{ [\kappa_0]_{HAU} \, [\hbar]_{HAU}^2 }{ [m_e]_{HAU} \, [e_0]_{HAU}^2}\\
#   &= \frac{ 1 \cdot 1^2 }{ 1 \cdot 1^2 } \, \frac{1.11265005620 \times 10^{-10} F/m \, (1.054571817 \times 10−34 Js)^2 }{ 9.1093837139 \times 10^{−31} kg \,(1.602176634 \times 10^{-19} C)^2}\\
#   &= 1 a_0 = 1 \, \textup{l}_{HAU}\\
#   &\Rightarrow \{ a_{0} \}_{HAU}=1; \qquad  [a_{0}]_{HAU}=5.2917720989499097 \times 10^{-11} m = a_0
#   \end{align*}
#
#   \begin{align*}
#   a_{0} &= \frac{\{\kappa_0\}_{RAU} \, \{\hbar\}_{RAU}^2 }{ \{m_e\}_{RAU} \, \{e_0\}_{RAU}^{2}} \, \frac{ [\kappa_0]_{RAU} \, [\hbar]_{RAU}^2 }{ [m_e]_{RAU} \, [e_0]_{RAU}^2}\\
#   &= \frac{ X_k \cdot X_h^2 }{ X_m \cdot X_e^2 } \, \frac{r_e 1.11265005620 \times 10^{-10} F/m \, (r_h 1.054571817 \times 10−34 Js)^2 }{ r_m 9.1093837139 \times 10^{−31} kg \,(r_e 1.602176634 \times 10^{-19} C)^2}\\
#   &= \frac{ X_k \cdot X_h^2 }{ X_m \cdot X_e^2 } \, \frac{r_e \, r_h^2 }{ r_m \,r_e^2} * a_0\\
#   &= \frac{ X_k \cdot X_h^2 }{ X_m \cdot X_e^2 } \, \textup{l}_{RAU}\\
#   &\Rightarrow \{ a_{0} \}_{RAU} = \frac{ X_k \cdot X_h^2 }{ X_m \cdot X_e^2 } = X_a ; \qquad  [a_{0}]_{RAU}=\frac{r_k \, r_h^2 }{ r_m \,r_e^2} a_0 = r_a \, a_0
#   \end{align*}

# %%
import atomic_units as au
from atomic_units import hartree_atomic_base_units as habu
rabu = au.AtomicBaseUnits(xh=4.0, xe=2.0, xm=10.0, xk=1.0)

hus = au.AtomicUnitSystem(base_units=habu)
rus = au.AtomicUnitSystem(base_units=rabu)

print(hus.length_unit)
print(rus.length_unit)
#print(hus.ureg("atomic_time"))
# Out:
# 5.2917721090397754e-11 meter
# 1.3229430272599438e-10 meter

# %% [markdown]
# ### Derived units
#
# - Energy:
#   Hartree energy $E_h$
#
# \begin{align*}
# E_h &= \frac{\hbar^2}{m_e a_0^2} \\
#     &= \frac{\{\hbar\}_{SI}^2}{\{m_e\}_{SI} \{a_0\}_{SI}^2} \; \frac{[\hbar]_{SI}^2}{ [m_e]_{SI} [a_0]_{SI}^2} \\
#     &= \frac{(1.054571817 \times 10^{-34})^2}{(9.1093837139 \times 10^{-31}) (5.2917720989499097 \times 10^{-11})^2} \, \frac{(\text{Js})^2}{\text{kg} \, \text{m}^2} \\
#     &= 4.3597447222071 \times 10^{-18} \, \text{J} \\
#     &\Rightarrow \{E_h\}_{SI} = 4.3597447222071 \times 10^{-18}; \qquad [E_h]_{SI} = \text{J}
# \end{align*}
#
# \begin{align*}
# E_h &= \frac{\{\hbar\}_{HAU}^2}{\{m_e\}_{HAU} \{a_0\}_{HAU}^2} \; \frac{ [\hbar]_{HAU}^2}{ [m_e]_{HAU} [a_0]_{HAU}^2} \\
#     &= \frac{1^2 \cdot 1^2}{1 \cdot 1 \cdot 1^2 \cdot 1^2} \, \frac{(1.054571817 \times 10^{-34} \, \text{Js})^2}{(9.1093837139 \times 10^{-31} \, \text{kg}) (5.2917720989499097 \times 10^{-11} \, \text{m})^2} \\
#     &= 1 \cdot E_h \\
#     &\Rightarrow \{E_h\}_{HAU} = 1; \qquad [E_h]_{HAU} = 4.3597447222071 \times 10^{-18} \, \text{J} = E_h
# \end{align*}
#
# \begin{align*}
# E_h &= \frac{\{\hbar\}_{RAU}^2}{\{m_e\}_{RAU} \{a_0\}_{RAU}^2} \; \frac{ [\hbar]_{RAU}^2}{ [m_e]_{RAU} [a_0]_{RAU}^2} \\
#     &= \frac{X_h^2}{X_m \cdot X_a^2} \, \frac{( r_h \, 1.054571817 \times 10^{-34} \, \text{Js})^2}{( r_m \, 9.1093837139 \times 10^{-31} \, \text{kg}) ( r_a \, 5.2917720989499097 \times 10^{-11} \, \text{m})^2} \\
#     &= \frac{X_h^2}{X_m \cdot X_a^2} \cdot \frac{r_h^2}{r_m \, r_a^2} \cdot E_h \\
#     &\Rightarrow \{E_h\}_{RAU} = \frac{X_h^2}{X_m \cdot X_a^2}; \qquad [E_h]_{RAU} = \frac{r_h^2}{r_m \, r_a^2} \cdot E_h = r_{en} \cdot E_h
# \end{align*}

# %%
import atomic_units as au

hus = au.AtomicUnitSystem(base_units=habu)
rus = au.AtomicUnitSystem(base_units=rabu)

print(hus.energy_unit)
print(rus.energy_unit)
# Out:
# 4.35974472220717e-18 joule
# 4.35974472220717e-19 joule

# %% [markdown]
# ### Derived units
#
# - Velocity:
#   Atomic unit of velocity $v_0$
#
# \begin{align*}
#     v_0 &= \frac{a_0 E_h}{\hbar} \\
#         &= \frac{\{
# E_h\}_{SI} \{a_0\}_{SI}}{\{\hbar\}_{SI}} \frac{[E_h]_{SI} [a_0]_{SI}}{ [\hbar]_{SI}} \\
#         &= \frac{(4.3597447222071 \times 10^{-18}) (5.2917720989499097 \times 10^{-11})}{(1.054571817 \times 10^{-34})}
#         \frac{\text{J} \cdot \text{m}}{\text{Js}} \\
#         &= 2.18769126364 \times 10^6 \, \text{m/s} \\
#         &\Rightarrow \{v_0\}_{SI} = 2.18769126364 \times 10^6; \qquad [v_0]_{SI} = \text{m/s}
# \end{align*}
#
# \begin{align*}
#     v_0 &= \frac{\{E_h\}_{HAU} \{a_0\}_{HAU}}{\{\hbar\}_{HAU}} \frac{ [E_h]_{HAU} [a_0]_{HAU}}{ [\hbar]_{HAU}} \\
#         &= \frac{1 \cdot 1}{1} \frac{(4.3597447222071 \times 10^{-18} \text{J}) (5.2917720989499097 \times 10^{-11} \text{m})}{(1.054571817 \times 10^{-34} \text{Js})} \\
#         &= 1 \cdot v_0 \\
#         &\Rightarrow \{v_0\}_{HAU} = 1; \qquad [v_0]_{HAU} = 2.18769126364 \times 10^6 \, \text{m/s} = v_0
# \end{align*}
#
# \begin{align*}
#     v_0 &= \frac{\{E_h\}_{RAU} \{a_0\}_{RAU}}{\{\hbar\}_{RAU}} \frac{ [E_h]_{RAU} [a_0]_{RAU}}{ [\hbar]_{RAU}} \\
#         &= \frac{X_{en} X_a}{X_\hbar} \cdot \frac{r_{en} r_a}{r_h} \cdot v_0 \\
#         &\Rightarrow \{v_0\}_{RAU} = \frac{X_{en} X_a}{X_\hbar}; \qquad [v_0]_{RAU} = \frac{r_{en} r_a}{r_{h}} \cdot v_0 = r_{vel} \cdot v_0
# \end{align*}

# %%
print(hus.velocity_unit)
print(rus.velocity_unit)
# Out:
# 2187691.2636451917 meter / second
# 2187691.2636451917 meter / second

# %%
print(hus.time_unit)
print(rus.time_unit)
# Out:
# 2.4188843265856803e-17 second
# 6.047210816464201e-17 second

# %%
print(hus.speed_of_light)
print(rus.speed_of_light)
print(hus.ureg("alpha").to_base_units())
# Out:
# 137.03599908356242
# 137.03599908356242
# 0.007297352569307099 dimensionless

# %% [markdown]
# # Set unified grid

# %%
import numpy as np

uxgrid_num = 8*1024
uxgrid_max = 50
uxgrid_min = -50

uxgrid_hus, uxgrid_hus_dx = np.linspace(uxgrid_min*(hus.ureg("nm")/hus.length_unit.to("nm")).magnitude,\
                          uxgrid_max*(hus.ureg("nm")/hus.length_unit.to("nm")).magnitude,\
                          uxgrid_num,retstep=True)

uxgrid_hus_width = (uxgrid_hus[-1] - uxgrid_hus[0])
to_nm_hus = (hus.ureg("nm")/hus.length_unit.to("nm")).magnitude
uxgrid_hus_step_size = uxgrid_hus_dx*hus.length_unit.to("nm")

print(uxgrid_hus_dx,uxgrid_hus_width,uxgrid_hus_width*hus.length_unit.to('nm'))
print(uxgrid_hus_step_size)

uxgrid_rus, uxgrid_rus_dx = np.linspace(uxgrid_min*(rus.ureg("nm")/rus.length_unit.to("nm")).magnitude,\
                          uxgrid_max*(rus.ureg("nm")/rus.length_unit.to("nm")).magnitude,\
                          uxgrid_num,retstep=True)

uxgrid_rus_width = (uxgrid_rus[-1] - uxgrid_rus[0])
to_nm_rus = (rus.ureg("nm")/rus.length_unit.to("nm")).magnitude
uxgrid_rus_step_size = uxgrid_rus_dx*rus.length_unit.to("nm")

print(uxgrid_rus_dx,uxgrid_rus_width,uxgrid_rus_width*rus.length_unit.to('nm'))
print(uxgrid_rus_step_size)
# Out:
# 0.23070762112346224 1889.7261246222793 99.99999999999999 nanometer
# 0.01220852154804053 nanometer
# 0.09228304844938492 755.8904498489119 100.0 nanometer
# 0.012208521548040533 nanometer

# %% [markdown]
# # Set model-potential

# %%
import matplotlib.pyplot as plt
import potentials as pots
import pint


well_depth = 1.0 # eV
well_depth_hus = (well_depth*hus.ureg("eV")/hus.energy_unit.to("eV")).magnitude
well_depth_rus = (well_depth*rus.ureg("eV")/rus.energy_unit.to("eV")).magnitude

well_width = 20.0 # nm
well_width_hus = well_width*to_nm_hus
well_width_rus = well_width*to_nm_rus


modelpot_hus=pots.SmoothStackPotential(uxgrid_hus,wallwidth=0,\
                                   wallheight=0,\
                                   welldepth=well_depth_hus,\
                                   wellwidth=well_width_hus,\
                                   wallrise = 2,\
                                   wellfall = 2)

modelpot_rus=pots.SmoothStackPotential(uxgrid_rus,wallwidth=0,\
                                   wallheight=0,\
                                   welldepth=well_depth_rus,\
                                   wellwidth=well_width_rus,\
                                   wallrise = 2,\
                                   wellfall = 2)

plt.plot(uxgrid_hus,modelpot_hus(0))
plt.plot(uxgrid_rus,modelpot_rus(0))
plt.xlabel("x [arb. u.]")
plt.ylabel("Pot. energy [arb. u.]")
plt.grid()
plt.show()

# %%
x = uxgrid_hus * hus.length_unit.to('nm')
y = modelpot_hus(0) * hus.energy_unit.to('eV')
y2 = modelpot_rus(0) * rus.energy_unit.to('eV')

plt.plot(x, y)
plt.plot(x, y2)
plt.xlabel("x [nm]")
plt.ylabel("Pot. energy [eV]")
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook.py:1345: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)

# %% [markdown]
# # Compute eigen states

# %%
import potentials as pots
import quantum_toolkit as quat
import scipy.sparse as sparse

zeropot_hus = pots.ZeroPotential(uxgrid_hus)
zeropot_rus = pots.ZeroPotential(uxgrid_rus)

ham_hus = quat.HamiltonOperator(uxgrid_hus,hbar=hus.hb,\
                                   me=hus.me,\
                                   charge=hus.e0,\
                                   scalarpot=modelpot_hus, vectorpot=zeropot_hus )

ham_rus = quat.HamiltonOperator(uxgrid_rus,hbar=rus.hb,\
                                   me=rus.me,\
                                   charge=rus.e0,\
                                   scalarpot=modelpot_rus, vectorpot=zeropot_rus )

# %%
print(ham_hus.diags[1])
print(ham_rus.diags[1])

plt.plot(np.arange(len(ham_hus.diags[1])),ham_hus.diags[1])
plt.plot(np.arange(len(ham_rus.diags[1])),ham_rus.diags[1])
plt.xlabel("n")
plt.ylabel("E")
plt.grid()
plt.show()
# Out:
# [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
# [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
#print(ham_hus.kineticenergyoperator)
#print(ham_rus.kineticenergyoperator)
print(ham_hus.kineticenergyoperator*hus.energy_unit.magnitude-ham_rus.kineticenergyoperator*rus.energy_unit.magnitude)
# Out:
# [[ 1.01072803e-29+0.j  1.01072803e-29+0.j  1.01072803e-29+0.j ...
#    1.01072803e-29+0.j  1.01072803e-29+0.j  1.01072803e-29+0.j]
#  [-2.02145607e-29+0.j -2.02145607e-29+0.j -2.02145607e-29+0.j ...
#   -2.02145607e-29+0.j -2.02145607e-29+0.j -2.02145607e-29+0.j]
#  [ 1.01072803e-29+0.j  1.01072803e-29+0.j  1.01072803e-29+0.j ...
#    1.01072803e-29+0.j  1.01072803e-29+0.j  1.01072803e-29+0.j]]

# %%
eigvals_hus, eigvecs_hus = sparse.linalg.eigsh(ham_hus(0), 20,which = 'SR')
eigvals_rus, eigvecs_rus = sparse.linalg.eigsh(ham_rus(0), 20,which = 'SR')

# %%
plt.scatter(np.arange(20),eigvals_hus)
plt.scatter(np.arange(20),eigvals_rus)
plt.xlabel("n")
plt.ylabel("E")
plt.grid()
plt.show()

# %%
plt.scatter(np.arange(20),eigvals_hus*hus.energy_unit.to('eV'))
plt.scatter(np.arange(20),eigvals_rus*rus.energy_unit.to('eV'))
plt.xlabel("n")
plt.ylabel("E [eV]")
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   _data = np.array(data, dtype=dtype, copy=copy,

# %% [markdown]
# # Check dispersion

# %%
disp_hus=quat.Dispersion(uxgrid_hus_dx,hbar=hus.hb, mass=hus.me)

en_max = 6 #eV
ukgrid_num = 41

en_max_hus = (en_max*hus.ureg("eV")/hus.energy_unit.to("eV")).magnitude
k_max_hus = disp_hus.energy2k(en_max_hus)

ukgrid_hus_max = k_max_hus
ukgrid_hus_min = -k_max_hus

print(f'k_max_hus {k_max_hus}')

ukgrid_hus, ukgrid_hus_dx = np.linspace(ukgrid_hus_min, ukgrid_hus_max,\
                               ukgrid_num,retstep=True)

ukgrid_hus_width = (ukgrid_hus[-1] - ukgrid_hus[0])
print(ukgrid_hus_dx,ukgrid_hus_width,ukgrid_hus_width*hus.wavenumber_unit.to('1/nm'))


disp_rus=quat.Dispersion(uxgrid_rus_dx,hbar=rus.hb, mass=rus.me)

en_max_rus = (en_max*rus.ureg("eV")/rus.energy_unit.to("eV")).magnitude
k_max_rus = disp_rus.energy2k(en_max_rus)

ukgrid_rus_max = k_max_rus
ukgrid_rus_min = -k_max_rus

print(f'k_max_rus {k_max_rus}')

ukgrid_rus, ukgrid_rus_dx = np.linspace(ukgrid_rus_min, ukgrid_rus_max,\
                               ukgrid_num,retstep=True)

ukgrid_rus_width = (ukgrid_rus[-1] - ukgrid_rus[0])
print(ukgrid_rus_dx,ukgrid_rus_width,ukgrid_rus_width*rus.wavenumber_unit.to('1/nm'))
# Out:
# k_max_hus 0.664723374554186
# 0.0332361687277093 1.329446749108372 157.85185205549453 / nanometer
# k_max_rus 1.6618084363854642
# 0.0830904218192732 3.3236168727709283 157.85185205549448 / nanometer

# %%
plt.scatter(ukgrid_hus,disp_hus.k2energy(ukgrid_hus))
plt.scatter(ukgrid_rus,disp_rus.k2energy(ukgrid_rus))
plt.xlabel("k")
plt.ylabel("E")
plt.grid()
plt.show()

# %%
plt.scatter(ukgrid_hus*hus.wavenumber_unit.to('1/nm'),disp_hus.k2energy(ukgrid_hus)*hus.energy_unit.to('eV'))
plt.scatter(ukgrid_rus*rus.wavenumber_unit.to('1/nm'),disp_rus.k2energy(ukgrid_rus)*rus.energy_unit.to('eV'))
plt.xlabel("k [1/nm]")
plt.ylabel("E [h.a.u]")
plt.grid()
plt.show()

# %% [markdown]
# # Check scattered states

# %%
import quantum_transport_toolkit as trat

particle_energy = 3.0 # eV
pe_hus = (particle_energy*hus.ureg("eV") / hus.energy_unit.to("eV")).magnitude
pe_rus = (particle_energy*rus.ureg("eV") / rus.energy_unit.to("eV")).magnitude

print(f'pe_hus {pe_hus} = {pe_hus}')
print(f'pe_rus {pe_rus} = {pe_rus}')


pk_hus = disp_hus.energy2k(pe_hus)
pk_rus = disp_rus.energy2k(pe_rus)

pk_hus_scaled = pk_hus*hus.wavenumber_unit.to('1/nm')
pk_rus_scaled = pk_rus*rus.wavenumber_unit.to('1/nm')

print(f'pk_hus {pk_hus} = {pk_hus_scaled}')
print(f'pk_rus {pk_rus} = {pk_rus_scaled}')

#qp_pk_hus, qp_mk_hus = trat.quasiparticles_at_given_energy(pe_hus,pk_hus,ham_hus,normed=False)
#qp_pk_rus, qp_mk_rus = trat.quasiparticles_at_given_energy(pe_rus,pk_rus,ham_rus,normed=False)

qp_pk_hus_normed, qp_mk_hus_normed = trat.quasiparticles_at_given_energy(pe_hus,pk_hus,ham_hus,normed=True)
qp_pk_rus_normed, qp_mk_rus_normed = trat.quasiparticles_at_given_energy(pe_rus,pk_rus,ham_rus,normed=True)
# Out:
# pe_hus 0.11024796652696306 = 0.11024796652696306
# pe_rus 1.1024796652696307 = 1.1024796652696307
# pk_hus 0.4697998705084302 = 55.78168490383216 / nanometer
# pk_rus 1.174499676271075 = 55.781684903832144 / nanometer
# 0.4920391983396117 0.04140517505122303
# 0.04920391983395462 0.0018533141841020723

# %%
print(qp_pk_hus_normed["energy"])
print(qp_pk_hus_normed["energy"]*hus.energy_unit.to("eV"))
print(qp_pk_rus_normed["energy"])
print(qp_pk_rus_normed["energy"]*rus.energy_unit.to("eV"))

print(hus.hb)
print(rus.hb)

#qp_pk_rus_normed["energy"]*rus.energy_unit.to("eV")/rus.hb.to("eV.s")
#print(qp_pk_rus_normed["energy"]*rus.energy_unit.to("eV")/rus.hb.to("eV.s"))
#print(qp_pk_hus_normed["energy"]*hus.energy_unit.to("eV")/hus.hb.to("eV.s"))
# Out:
# 0.11024796652696306
# 3.0 electron_volt
# 1.1024796652696307
# 3.0000000000000004 electron_volt
# 1.0
# 4.0

# %%
x_hus = uxgrid_hus*hus.length_unit.to("nm")
x_rus = uxgrid_rus*rus.length_unit.to("nm")

psi_hus_normed=qp_pk_hus_normed["state"]["value"]#/hus.energy_unit.to("eV").magnitude
psi_rus_normed=qp_pk_rus_normed["state"]["value"]#/rus.energy_unit.to("eV").magnitude

#plt.plot(uxgrid_hus*hus.length_unit.to("nm"),modelpot_hus(0)*hus.energy_unit.to("eV"),"-.",label="Pot")
plt.plot(x_hus,np.real(psi_hus_normed),label="Re_hus_normed")
plt.plot(x_hus,np.imag(psi_hus_normed),label="Im_hus_normed")
#plt.plot(x_hus,np.abs(psi_hus)**2,label="Abs_hus")
#plt.plot(x_hus,5.8*np.abs(psi_hus_normed)**2,label="Abs_hus_normed")

#plt.plot(uxgrid_rus*rus.length_unit.to("nm"),modelpot_rus(0)*rus.energy_unit.to("eV"),"--",label="Pot")
plt.plot(x_rus,1*np.real(psi_rus_normed),"-.",label="Re_rus_normed")
plt.plot(x_rus,1*np.imag(psi_rus_normed),"-.",label="Im_rus_normed")
#plt.plot(x_rus,12*np.abs(psi_rus)**2,label="Abs_rus")
#plt.plot(x_rus,0.85*np.abs(psi_rus_normed)**2,label="Abs_rus_normed")

plt.xlabel("x [nm]")
plt.ylabel("Pot. energy [eV]")
plt.xlim([-16, -8])
plt.legend()
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook.py:1345: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)

# %% [markdown]
# # Test external electric field scaling

# %%
to_fs_hus = (hus.ureg("fs")/hus.time_unit.to("fs")).magnitude
to_fs_rus = (rus.ureg("fs")/rus.time_unit.to("fs")).magnitude
print(to_fs_hus,to_fs_rus)

t_start=0
t_stop=100.0 # fs
utgrid_num = 16384

t_start_hus = t_start*to_fs_hus
t_stop_hus = t_stop*to_fs_hus
t_start_rus = t_start*to_fs_rus
t_stop_rus = t_stop*to_fs_rus

utgrid_hus, utgrid_hus_dt = np.linspace(t_start_hus,t_stop_hus,utgrid_num,retstep=True)
utgrid_rus, utgrid_rus_dt = np.linspace(t_start_rus,t_stop_rus,utgrid_num,retstep=True)

print(utgrid_hus[-1],utgrid_rus[-1])
print(utgrid_hus_dt,utgrid_rus_dt)
# Out:
# 41.34137333518245 16.53654933407298
# 4134.137333518245 1653.654933407298
# 0.2523431199119969 0.10093724796479875

# %%
spot_size = 14 # in nm
magnitude_of_electric_field = 1.0e8 # in V/m
central_wavelength = 800 # in nm
central_wavelength_hus = central_wavelength*to_nm_hus
central_wavelength_rus = central_wavelength*to_nm_rus
print(central_wavelength_hus,central_wavelength_rus)

omega_hus = 2*np.pi*hus.speed_of_light/central_wavelength_hus
omega_rus = 2*np.pi*rus.speed_of_light/central_wavelength_rus
print(omega_hus,omega_rus)
num_of_cycles = 5 # one cycle is around 2.66 fs

t_min_hus = t_min_rus = 0
t_max_hus = num_of_cycles*2*np.pi/omega_hus
t_max_rus = num_of_cycles*2*np.pi/omega_rus
print("pulse length hus:",t_max_hus,t_max_hus*hus.time_unit.to("fs"))
print("pulse length rus:",t_max_rus,t_max_rus*rus.time_unit.to("fs"))

s_min = -0.5*spot_size
s_max = 0.5*spot_size

s_min_hus = s_min*to_nm_hus
s_max_hus = s_max*to_nm_hus
s_min_rus = s_min*to_nm_rus
s_max_rus = s_max*to_nm_rus

magnitude_hus = (magnitude_of_electric_field*hus.ureg("V/m")/hus.electric_field_unit.to("V/m")).magnitude
magnitude_rus = (magnitude_of_electric_field*rus.ureg("V/m")/rus.electric_field_unit.to("V/m")).magnitude
print(magnitude_hus,magnitude_rus)#,magnitude_hus/magnitude_rus)

beta=0.1
beta_hus = beta
beta_rus = beta*to_nm_hus/to_nm_rus
print(beta_hus,beta_rus,beta_hus/beta_rus)

laserpot_hus = pots.SmoothLaserPotential(uxgrid_hus, spatial_min = s_min_hus, spatial_max = s_max_hus,\
                                            temporal_max=t_max_hus,temporal_min=t_min_hus,noc=num_of_cycles,\
                                            amplitude=magnitude_hus,beta=beta_hus)

laserpot_rus = pots.SmoothLaserPotential(uxgrid_rus, spatial_min = s_min_rus, spatial_max = s_max_rus,\
                                            temporal_max=t_max_rus,temporal_min=t_min_rus,noc=num_of_cycles,\
                                            amplitude=magnitude_rus,beta=beta_rus)

print(laserpot_hus.omega0,laserpot_rus.omega0)

# laserpot_cep0 = pots.SmoothLaserPotential(uxgrid,\
#                                     spatial_min = -0.5*spot_size,\
#                                     spatial_max = 0.5*spot_size,beta=0.25)
# Out:
# 15117.808996978234 6047.123598791295
# 0.05695419066139921 0.142385476653498
# pulse length hus: 551.5999116319657 13.34256380792608 femtosecond
# pulse length rus: 220.63996465278635 13.342563807926085 femtosecond
# 0.00019446903811524464 0.002430862976440558
# 0.1 0.24999999999999997 0.4000000000000001
# 0.05695419066139921 0.142385476653498

# %%
plt.plot(uxgrid_hus, laserpot_hus(laserpot_hus.temporal_width/2),label="laser hus")
plt.plot(uxgrid_rus, laserpot_rus(laserpot_rus.temporal_width/2),"-.",label="laser rus")
#plt.xlim([-12, 12])
plt.legend()
plt.xlabel("x [nm]")
plt.ylabel("Field strength [GV/m]")
plt.grid()
plt.show()

# %%
plt.plot(uxgrid_hus*hus.length_unit.to("nm"), laserpot_hus(laserpot_hus.temporal_width/2)*hus.electric_field_unit.to("GV/m").magnitude,label="laser hus")
plt.plot(uxgrid_rus*rus.length_unit.to("nm"), laserpot_rus(laserpot_rus.temporal_width/2)*rus.electric_field_unit.to("GV/m").magnitude,"-.",label="laser rus")
plt.xlim([-12, 12])
plt.legend()
plt.xlabel("x [nm]")
plt.ylabel("Field strength [GV/m]")
plt.grid()
plt.show()

# %%
plt.plot(utgrid_hus*hus.time_unit.to("fs"), laserpot_hus.value_at(0.0,utgrid_hus)*hus.electric_field_unit.to("GV/m").magnitude,label="hus")
plt.plot(utgrid_rus*rus.time_unit.to("fs"), laserpot_rus.value_at(0.0,utgrid_rus)*rus.electric_field_unit.to("GV/m").magnitude,"-.",label="rus")
plt.xlabel("time [fs]")
plt.ylabel("Field strength [GV/m]")
plt.legend()
plt.xlim([0, 20])
plt.grid()
plt.show()

# %% [markdown]
# # Generate VCAP-s

# %%
v_cap_hus=quat.vcap_generator(uxgrid_hus,param_lambda0 = 0.025)

# plt.plot(uxgrid_hus,np.abs(v_cap_hus[0]),label="|Vcap[0]|")
# plt.plot(uxgrid_hus,np.angle(v_cap_hus[0]),label="Angle{Vcap[0]}")
# plt.legend()
# plt.grid()
# plt.show()

# plt.plot(uxgrid_hus,np.real(v_cap_hus[1]),label="Re{Vcap[1]}")
# plt.plot(uxgrid_hus,np.imag(v_cap_hus[1]),label="Im{Vcap[1]}")
# plt.legend()
# plt.grid()
# plt.show()

# plt.plot(uxgrid_hus,np.real(v_cap_hus[2]),label="Re{Vcap[2]}")
# plt.plot(uxgrid_hus,np.imag(v_cap_hus[2]),label="Im{Vcap[2]}")
# plt.legend()
# plt.grid()
# plt.show()

# %%
v_cap_rus=quat.vcap_generator(uxgrid_rus,param_lambda0 = 0.06)

# plt.plot(uxgrid_rus,np.abs(v_cap_rus[0]),label="|Vcap[0]|")
# plt.plot(uxgrid_rus,np.angle(v_cap_rus[0]),label="Angle{Vcap[0]}")
# plt.legend()
# plt.grid()
# plt.show()

# plt.plot(uxgrid_rus,np.real(v_cap_rus[1]),label="Re{Vcap[1]}")
# plt.plot(uxgrid_rus,np.imag(v_cap_rus[1]),label="Im{Vcap[1]}")
# plt.legend()
# plt.grid()
# plt.show()

# plt.plot(uxgrid_rus,np.real(v_cap_rus[2]),label="Re{Vcap[2]}")
# plt.plot(uxgrid_rus,np.imag(v_cap_rus[2]),label="Im{Vcap[2]}")
# plt.legend()
# plt.grid()
# plt.show()

# %%
plt.plot(uxgrid_hus*hus.length_unit.to("nm"),np.real(v_cap_hus[2]),label="Re{Vcap[2]}")
plt.plot(uxgrid_hus*hus.length_unit.to("nm"),np.imag(v_cap_hus[2]),label="Im{Vcap[2]}")
plt.plot(uxgrid_rus*rus.length_unit.to("nm"),np.real(v_cap_rus[2]),label="Re{Vcap[2]}")
plt.plot(uxgrid_rus*rus.length_unit.to("nm"),np.imag(v_cap_rus[2]),label="Im{Vcap[2]}")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Test/compare the dynamics of the Shrödinger equation

# %%
print(qp_pk_hus_normed["energy"])
print(qp_pk_hus_normed["energy"]*hus.energy_unit.to("eV"))
print(qp_pk_rus_normed["energy"])
print(qp_pk_rus_normed["energy"]*rus.energy_unit.to("eV"))

print(hus.hb)
print(rus.hb)
# Out:
# 0.11024796652696306
# 3.0 electron_volt
# 1.1024796652696307
# 3.0000000000000004 electron_volt
# 1.0
# 4.0

# %%
window_start = -5  # Az ablak kezdete
window_end = 5     # Az ablak vége

k_package = 50.0

k_package_hus = (k_package*hus.ureg("1/nm")/hus.wavenumber_unit.to("1/nm")).magnitude
k_package_rus = (k_package*rus.ureg("1/nm")/rus.wavenumber_unit.to("1/nm")).magnitude
print(k_package_hus,k_package_rus)
print(k_package_hus*hus.wavenumber_unit.to("1/nm"))
print(k_package_rus*rus.wavenumber_unit.to("1/nm"))

window_start_hus = window_start * to_nm_hus
window_end_hus = window_end * to_nm_hus
window_start_rus = window_start * to_nm_rus
window_end_rus = window_end * to_nm_rus

carrier_hus=np.heaviside(uxgrid_hus - window_start_hus, 1)\
                         * np.heaviside(window_end_hus - uxgrid_hus, 1)\
                         * np.sin( np.pi * (uxgrid_hus - window_start_hus) / (window_end_hus - window_start_hus))**2
psi1_hus_value=np.array(carrier_hus*np.exp(1j*k_package_hus*uxgrid_hus),\
                        dtype=np.complex128)

carrier_rus=np.heaviside(uxgrid_rus - window_start_rus, 1)\
                         * np.heaviside(window_end_rus - uxgrid_rus, 1)\
                         * np.sin( np.pi * (uxgrid_rus - window_start_rus) / (window_end_rus - window_start_rus))**2
psi1_rus_value=np.array(carrier_rus*np.exp(1j*k_package_rus*uxgrid_rus),\
                        dtype=np.complex128)

psi1_hus=quat.Wavefunction(grid=uxgrid_hus, value=psi1_hus_value, normed=False)
psi1_rus=quat.Wavefunction(grid=uxgrid_rus, value=psi1_rus_value, normed=False)
# Out:
# 0.4211058444347522 1.0527646110868805
# 50.0 / nanometer
# 50.0 / nanometer

# %%
plt.plot(uxgrid_rus*rus.length_unit.to("nm"),np.abs(psi1_rus_value),label="Abs[psi1_rus]")
plt.plot(uxgrid_rus*rus.length_unit.to("nm"),np.real(psi1_rus_value),label="Re[psi1_rus]")

plt.plot(uxgrid_hus*hus.length_unit.to("nm"),np.abs(psi1_hus_value),label="psi1_hus")
plt.xlabel("x [nm]")
plt.ylabel("Wavefunction")
plt.xlim([-10, 10])
plt.legend()
plt.grid()
plt.show()

# %%
hham_hus = quat.HamiltonOperator(uxgrid_hus,hbar=hus.hb,\
                                   me=hus.me,\
                                   charge=hus.e0,\
                                   scalarpot=zeropot_hus,\
                                   vectorpot=zeropot_hus)
hham_hus.vcap(v_cap_hus)
solver_hus=quat.CntdSes(psi1_hus_value, hham_hus, dt=utgrid_hus_dt)

hham_rus = quat.HamiltonOperator(uxgrid_rus,hbar=rus.hb,\
                                   me=rus.me,\
                                   charge=rus.e0,\
                                   scalarpot=zeropot_rus,\
                                   vectorpot=zeropot_rus)
hham_rus.vcap(v_cap_rus)
solver_rus=quat.CntdSes(psi1_rus_value, hham_rus, dt=utgrid_rus_dt)

# %%
psi1_time_evolution_hus=np.zeros((uxgrid_num,utgrid_num),dtype=np.complex128)
psi1_time_evolution_hus[:,0]=psi1_hus_value
for i in range(1,utgrid_num):
    psi1_time_evolution_hus[:,i]=solver_hus.step_one()

# %%
X_hus,Y_hus = np.meshgrid(uxgrid_hus*hus.length_unit.to("nm"),utgrid_hus[:]*hus.time_unit.to("fs"))
Z_hus=np.transpose(np.abs(psi1_time_evolution_hus)**2)

pcm_hus = plt.pcolormesh(X_hus,Y_hus,Z_hus,cmap ='bwr',shading='auto') #plt.pcolormesh(X, Y, Z, cmap ='bwr', vmin = z_min, vmax = z_max)
plt.colorbar(pcm_hus)
plt.title('Abs[Psi]^2', fontweight ="bold")
plt.xlabel("x [nm]")
plt.ylabel("time [fs]")
#plt.xlim([-12, 12])
#plt.ylim(0,2*laserpot_hus.temporal_width*hus.time_unit.to("fs").magnitude)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook.py:733: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   x = np.array(x, subok=True, copy=copy)

# %%
psi1_time_evolution_rus=np.zeros((uxgrid_num,utgrid_num),dtype=np.complex128)
psi1_time_evolution_rus[:,0]=psi1_rus_value
for i in range(1,utgrid_num):
    psi1_time_evolution_rus[:,i]=solver_rus.step_one()

# %%
X_rus,Y_rus = np.meshgrid(uxgrid_rus*rus.length_unit.to("nm"),utgrid_rus[:]*rus.time_unit.to("fs"))
Z_rus=np.transpose(np.abs(psi1_time_evolution_rus)**2)
pcm_rus = plt.pcolormesh(X_rus,Y_rus,Z_rus,cmap ='bwr',shading='auto') #plt.pcolormesh(X, Y, Z, cmap ='bwr', vmin = z_min, vmax = z_max)
plt.colorbar(pcm_rus)
plt.title('Abs[Psi]^2', fontweight ="bold")
plt.xlabel("x [nm]")
plt.ylabel("time [fs]")
#plt.xlim([-12, 12])
#plt.ylim(0,2*laserpot_hus.temporal_width*hus.time_unit.to("fs").magnitude)
plt.show()

# %% [markdown]
# # Check quantum toolkit

# %%
te_hus=quat.SplitTimeEvolutionCalculator(psi0_omega=qp_pk_hus_normed["energy"]/hus.hb,\
        psi0_initial = qp_pk_hus_normed["state"],\
        #psi1_initial=psi1_hus,\
        scalarpot = modelpot_hus,\
        vectorpot=laserpot_hus,\
        me=hus.me, hbar=hus.hb,\
        charge=hus.e0,\
        dt=utgrid_hus_dt, t_start=t_start_hus, t_stop=t_stop_hus,\
        vcap=v_cap_hus)

te_rus=quat.SplitTimeEvolutionCalculator(psi0_omega=qp_pk_rus_normed["energy"]/rus.hb,\
        psi0_initial = qp_pk_rus_normed["state"],\
        #psi1_initial=psi1_rus,\
        scalarpot = modelpot_rus,\
        vectorpot=laserpot_rus,\
        me=rus.me, hbar=rus.hb,\
        charge=rus.e0,\
        dt=utgrid_rus_dt, t_start=t_start_rus, t_stop=t_stop_rus,\
        vcap=v_cap_rus)

# %%
print(te_hus.boundary.ham1(50).toarray())
# Out:
# [[0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  ...
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]]

# %%
te_hus.run()

# %%
te_rus.run()

# %%
X,Y = np.meshgrid(uxgrid_hus*hus.length_unit.to("nm"),utgrid_hus[:-1]*hus.time_unit.to("fs"))
Z=np.transpose(np.abs(te_hus.psi1_time_evolution["value"])**2)

# %%
#z_min, z_max = -np.abs(Z).max(), np.abs(Z).max()
    
pcm = plt.pcolormesh(X,Y,Z,cmap ='bwr',shading='auto') #plt.pcolormesh(X, Y, Z, cmap ='bwr', vmin = z_min, vmax = z_max)
plt.colorbar(pcm)
plt.title('Prob. dens. width external field', fontweight ="bold")
plt.xlabel("x [nm]")
plt.ylabel("time [fs]")
#plt.xlim([-12, 12])
plt.ylim(0,2*laserpot_hus.temporal_width*hus.time_unit.to("fs").magnitude)
plt.show()

# %%
X2,Y2 = np.meshgrid(uxgrid_rus*rus.length_unit.to("nm"),utgrid_rus[:-1]*rus.time_unit.to("fs"))
Z2=np.transpose(np.abs(te_rus.psi1_time_evolution["value"])**2)

# %%
pcm2 = plt.pcolormesh(X2,Y2,Z2,cmap ='bwr',shading='auto') #plt.pcolormesh(X, Y, Z, cmap ='bwr', vmin = z_min, vmax = z_max)
plt.colorbar(pcm2)
plt.title('Prob. dens. width external field', fontweight ="bold")
plt.xlabel("sapce [nm]")
plt.ylabel("time [fs]")
#plt.xlim([-12, 12])
plt.ylim(0,2*laserpot_rus.temporal_width*rus.time_unit.to("fs").magnitude)
plt.show()

# %%
X3,Y3 = np.meshgrid(uxgrid_rus*rus.length_unit.to("nm"),utgrid_rus[:-1]*rus.time_unit.to("fs"))
Z3=np.transpose(np.real(te_rus.psi0_time_evolution["value"]))

pcm3 = plt.pcolormesh(X3,Y3,Z3,cmap ='bwr',shading='auto') #plt.pcolormesh(X, Y, Z, cmap ='bwr', vmin = z_min, vmax = z_max)
plt.colorbar(pcm3)
plt.title('Re\{Psi0\}', fontweight ="bold")
plt.xlabel("sapce [nm]")
plt.ylabel("time [fs]")
plt.xlim([-15, -5])
#plt.ylim(0,10)
plt.show()

X4,Y4 = np.meshgrid(uxgrid_hus*hus.length_unit.to("nm"),utgrid_hus[:-1]*hus.time_unit.to("fs"))
Z4=np.transpose(np.real(te_hus.psi0_time_evolution["value"]))
pcm4 = plt.pcolormesh(X4,Y4,Z4,cmap ='bwr',shading='auto') #plt.pcolormesh(X, Y, Z, cmap ='bwr', vmin = z_min, vmax = z_max)
plt.colorbar(pcm4)
plt.title('Re\{Psi0\}', fontweight ="bold")
plt.xlabel("sapce [nm]")
plt.ylabel("time [fs]")
plt.xlim([-15, -5])
#plt.ylim(0,10)
plt.show()

# %%
X5,Y5 = np.meshgrid(uxgrid_rus*rus.length_unit.to("nm"),utgrid_rus[:-1]*rus.time_unit.to("fs"))
Z5=np.transpose(np.real(te_rus.psi_time_evolution["value"]))

pcm5 = plt.pcolormesh(X5,Y5,Z5,cmap ='bwr',shading='auto') #plt.pcolormesh(X, Y, Z, cmap ='bwr', vmin = z_min, vmax = z_max)
plt.colorbar(pcm5)
plt.title('Re\{Psi\}', fontweight ="bold")
plt.xlabel("sapce [nm]")
plt.ylabel("time [fs]")
plt.xlim([-15, -5])
#plt.ylim(0,10)
plt.show()

X6,Y6 = np.meshgrid(uxgrid_hus*hus.length_unit.to("nm"),utgrid_hus[:-1]*hus.time_unit.to("fs"))
Z6=np.transpose(np.real(te_hus.psi_time_evolution["value"]))
pcm6 = plt.pcolormesh(X6,Y6,Z6,cmap ='bwr',shading='auto') #plt.pcolormesh(X, Y, Z, cmap ='bwr', vmin = z_min, vmax = z_max)
plt.colorbar(pcm6)
plt.title('Re\{Psi\}', fontweight ="bold")
plt.xlabel("sapce [nm]")
plt.ylabel("time [fs]")
plt.xlim([-15, -5])
#plt.ylim(0,10)
plt.show()

# %%
X7,Y7 = np.meshgrid(uxgrid_rus*rus.length_unit.to("nm"),utgrid_rus[:-1]*rus.time_unit.to("fs"))
Z7=np.transpose(np.abs(te_rus.psi_time_evolution["value"]-te_hus.psi_time_evolution["value"]))

pcm7 = plt.pcolormesh(X7,Y7,Z7,cmap ='bwr',shading='auto') #plt.pcolormesh(X, Y, Z, cmap ='bwr', vmin = z_min, vmax = z_max)
plt.colorbar(pcm7)
plt.title('Re\{Psi\}', fontweight ="bold")
plt.xlabel("sapce [nm]")
plt.ylabel("time [fs]")
#plt.xlim([-15, -5])
#plt.ylim(0,10)
plt.show()

# %%
X8,Y8 = np.meshgrid(uxgrid_rus*rus.length_unit.to("nm"),utgrid_rus[:-1]*rus.time_unit.to("fs"))
Z8=np.transpose(np.abs(te_rus.psi1_time_evolution["value"]-te_hus.psi1_time_evolution["value"]))

pcm8 = plt.pcolormesh(X8,Y8,Z8,cmap ='bwr',shading='auto') #plt.pcolormesh(X, Y, Z, cmap ='bwr', vmin = z_min, vmax = z_max)
plt.colorbar(pcm8)
plt.title('Re\{Psi\}', fontweight ="bold")
plt.xlabel("sapce [nm]")
plt.ylabel("time [fs]")
#plt.xlim([-15, -5])
#plt.ylim(0,10)
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
X8,Y8 = np.meshgrid(uxgrid_rus*rus.length_unit.to("nm"),utgrid_rus[:-1]*rus.time_unit.to("fs"))
Z8=np.transpose(np.abs(te_rus.psi1_time_evolution["value"]-te_hus.psi1_time_evolution["value"]))

pcm8 = plt.pcolormesh(X8,Y8,Z8,cmap ='bwr',shading='auto',vmax = 2e-3) #plt.pcolormesh(X, Y, Z, cmap ='bwr', vmin = z_min, vmax = z_max)
plt.colorbar(pcm8)
plt.title('Re\{Psi\}', fontweight ="bold")
plt.xlabel("sapce [nm]")
plt.ylabel("time [fs]")
#plt.xlim([-15, -5])
#plt.ylim(0,10)
plt.show()

# %%
X9,Y9 = np.meshgrid(uxgrid_rus*rus.length_unit.to("nm"),utgrid_rus[:-1]*rus.time_unit.to("fs"))
Z9=np.transpose(np.abs(te_rus.psi0_time_evolution["value"]-te_hus.psi0_time_evolution["value"]))

pcm9 = plt.pcolormesh(X9,Y9,Z9,cmap ='bwr',shading='auto') #plt.pcolormesh(X, Y, Z, cmap ='bwr', vmin = z_min, vmax = z_max)
plt.colorbar(pcm9)
plt.title('Re\{Psi\}', fontweight ="bold")
plt.xlabel("sapce [nm]")
plt.ylabel("time [fs]")
#plt.xlim([-15, -5])
#plt.ylim(0,10)
plt.show()

# %%
time_index = 0

phi_hus=te_hus.psi_time_evolution["value"][:,time_index]
phi_rus=te_rus.psi_time_evolution["value"][:,time_index]

#print(phi_hus.shape)

plt.plot(x_hus,np.real(phi_hus),label="Re_hus_normed")
#plt.plot(x_hus,np.imag(phi_hus),label="Im_hus_normed")

plt.plot(x_rus,np.real(phi_rus),"o",label="Re_rus_normed")
#plt.plot(x_rus,np.imag(phi_rus),"-.",label="Im_rus_normed")

plt.xlabel("x [nm]")
plt.ylabel("Pot. energy [eV]")
plt.xlim([-10, 10])
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Make better fitting for $A_i$,$A_r$,$A_t$,T,R parameters

# %%
fit_length = 30 # nm
fit_num =  int(((fit_length*rus.length_unit.to("nm"))/( uxgrid_rus_dx*rus.length_unit.to("nm") )).magnitude) # np.abs(np.array((uxgrid_rus*rus.length_unit.to("nm")).magnitude) - (fit_length*uxgrid_rus*rus.length_unit.to("nm")).magnitude).argmin()#1300
print(fit_num)
# Out:
# 325

# %%
from numpy import linalg

def fleft(x, k, ai, ar):
    return ai * np.exp(1j*k*x) + ar * np.exp(-1j*k*x)

def fright(x, k, at):
    return at * np.exp(1j*k*x)

#fit_num=200
xdata_left = qp_pk_rus["state"]["grid"][:fit_num]
xdata_right = qp_pk_rus["state"]["grid"][-fit_num:]
ydata_left = qp_pk_rus["state"]["value"][:fit_num]
ydata_right = qp_pk_rus["state"]["value"][-fit_num:]

# Solve with least-squares solution
A = np.zeros([fit_num,2],dtype=np.complex128)
A[:,0]=np.exp(1j*pk_rus*xdata_left) # incoming wave
A[:,1]=np.exp(-1j*pk_rus*xdata_left) # reflected wave
b=qp_pk_rus["state"]["value"][:fit_num].T

x_lstsq = linalg.lstsq(A,b,rcond=None)[0] # computing the numpy solution
ai=x_lstsq[0]
ar=x_lstsq[1]

print(x_lstsq,type(x_lstsq))
print(ai,ar)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 10
#       7     return at * np.exp(1j*k*x)
#       9 #fit_num=200
# ---> 10 xdata_left = qp_pk_rus["state"]["grid"][:fit_num]
#      11 xdata_right = qp_pk_rus["state"]["grid"][-fit_num:]
#      12 ydata_left = qp_pk_rus["state"]["value"][:fit_num]
#
# NameError: name 'qp_pk_rus' is not defined

# %%
plt.plot(xdata_left,np.real(ydata_left),label="Re original")
plt.plot(xdata_left,np.imag(ydata_left),label="Im original")
plt.plot(xdata_left,np.abs(ydata_left),label="Abs original")

yfit_left = fleft(xdata_left,pk_rus,ai,ar)
plt.plot(xdata_left,np.real(yfit_left),"-.",label="Re fit",color="red")
plt.plot(xdata_left,np.imag(yfit_left),"-.",label="Im fit",color="green")


plt.xlabel("x [nm]")
plt.ylabel("Psi [1/sqrt(nm)]")
plt.legend()
plt.grid()
plt.show()

# %%
import quantum_toolkit as qtk
import quantum_transport_toolkit as qttk

def amplitudes2(k: float,wf: qtk.Wavefunction,fit_num: int = 100):
    """
    Compute the amplitudes of the incoming and reflected waves
    for a given wavefunction at a given energy. The amplitudes
    are computed by fitting the wavefunction to the sum of
    incoming and reflected waves.        
    """
    # Split the wavefunction into left and right parts

    x_left = wf["grid"][:fit_num]
    x_right = wf["grid"][-fit_num:]

    # Solve with least-squares solution
    A = np.zeros([fit_num,2],dtype=np.complex128)
    A[:,0]=np.exp(1j*k*x_left) # incoming wave on the left
    A[:,1]=np.exp(-1j*k*x_left) # reflected wave on the left
    b=wf["value"][:fit_num].T

    x_lstsq = linalg.lstsq(A,b,rcond=None)[0] # computing the numpy solution
    a_left=x_lstsq[0] # complex amplitude of positive propagating wave on the left
    b_left=x_lstsq[1] # complex amplitude of negative propagating wave on the left
    
    A = np.zeros([fit_num,2],dtype=np.complex128)
    A[:,0]=np.exp(1j*k*x_right) # incoming wave on the right
    A[:,1]=np.exp(-1j*k*x_right) # reflected wave on the right
    b=wf["value"][-fit_num:].T

    x_lstsq = linalg.lstsq(A,b,rcond=None)[0] # computing the numpy solution
    a_right=x_lstsq[0] # complex amplitude of positive propagating wave on the right
    b_right=x_lstsq[1] # complex amplitude of negative propagating wave on the right

    return (a_left,b_left,a_right,b_right)

a_left,b_left,a_right,b_right = amplitudes2(pk_rus,qp_pk_rus["state"])

print(a_left,b_left,a_right,b_right)
print(qttk.input_amplitude(pk_rus,qp_pk_rus["state"]))
print(qttk.input_amplitude2(pk_rus,qp_pk_rus["state"]))
# Out:
# (-0.10537985329454114-0.05818682583723731j) (-0.0005921771721981474-0.027630026447664414j) (0.11713474572294165-0.002510476152635393j) (3.9850128676721614e-16+1.8963100038528361e-16j)
# (-0.10537985329449301-0.05818682583728449j)
# (-0.10537985329454114-0.05818682583723731j)

# %%
plt.plot(xdata_right,np.real(ydata_right),label="Re original")
plt.plot(xdata_right,np.imag(ydata_right),label="Im original")
plt.plot(xdata_right,np.abs(ydata_right),label="Abs original")

yfit_right = fright(xdata_right,pk_rus,a_right)
plt.plot(xdata_right,np.real(yfit_right),"-.",label="Re fit",color="red")   
plt.plot(xdata_right,np.imag(yfit_right),"-.",label="Im fit",color="green")

plt.xlabel("x [nm]")
plt.ylabel("Psi [1/sqrt(nm)]")
plt.legend()
plt.grid()
plt.show()

# %%
print(qttk.input_amplitude(pk_rus,qp_pk_rus["state"]))
print(qttk.input_amplitude2(pk_rus,qp_pk_rus["state"]))

print(qttk.transmission_amplitude(pk_rus,qp_pk_rus["state"]))
print(qttk.transmission_amplitude2(pk_rus,qp_pk_rus["state"]))

print(qttk.reflection_amplitude(pk_rus,qp_pk_rus["state"]))
print(qttk.reflection_amplitude2(pk_rus,qp_pk_rus["state"]))

print(qttk.transmission(pk_rus,qp_pk_rus["state"]))
print(qttk.transmission2(pk_rus,qp_pk_rus["state"]))

print(qttk.reflection(pk_rus,qp_pk_rus["state"]))
print(qttk.reflection2(pk_rus,qp_pk_rus["state"]))

print(qttk.reflection(pk_rus,qp_pk_rus["state"])+qttk.transmission(pk_rus,qp_pk_rus["state"]))
print(qttk.reflection2(pk_rus,qp_pk_rus["state"])+qttk.transmission2(pk_rus,qp_pk_rus["state"]))
# Out:
# (-0.10537985329449301-0.05818682583728449j)
# (-0.10537985329454114-0.05818682583723731j)
# (0.11713474572294011-0.002510476152708189j)
# (0.11713474572294165-0.002510476152635393j)
# (-0.0005921771721947488-0.027630026447654405j)
# (-0.0005921771721981474-0.027630026447664414j)
# 0.9472921775786225
# 0.947292177578318
# 0.0527078224217334
# 0.052707822421754924
# 1.000000000000356
# 1.0000000000000728
